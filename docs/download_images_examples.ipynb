# %% [markdown]
# # Download Pilot Images from Packaged Metadata
# This notebook shows how to load the packaged JUMP pilot metadata and download a subset of TIFF images.

# %%
from pathlib import Path

from jump_image_datasets.jump_pilot import image_downloader, image_metadata

# %%
img_metadf = image_metadata.load_metadata(use_cache=True)
print(f"Metadata shape: {img_metadf.shape}")
img_metadf.head()
# Out:
# Metadata shape: (1495400, 32)
#   Metadata_Plate Metadata_Well  Metadata_Site  Metadata_AbsPositionZ  \
# 0     BR00116991           A01              1               0.134679
# 1     BR00116991           A01              2               0.134679
# 2     BR00116991           A01              3               0.134673
# 3     BR00116991           A01              4               0.134674
# 4     BR00116991           A01              5               0.134681
#
#                 Metadata_AbsTime  Metadata_BinningX  Metadata_BinningY  \
# 0   2020-11-05T19:55:20.94-05:00                  2                  2
# 1  2020-11-05T19:55:22.673-05:00                  2                  2
# 2  2020-11-05T19:55:24.217-05:00                  2                  2
# 3  2020-11-05T19:55:25.747-05:00                  2                  2
# 4  2020-11-05T19:55:27.243-05:00                  2                  2
#
#    Metadata_ChannelID Metadata_ChannelName  Metadata_Col  ...  \
# 0                   5                  DNA             1  ...
# 1                   5                  DNA             1  ...
# 2                   5                  DNA             1  ...
# 3                   5                  DNA             1  ...
# 4                   5                  DNA             1  ...
#
#    Metadata_PositionX  Metadata_PositionY  Metadata_PositionZ  Metadata_Row  \
# 0           -0.000323            0.000323           -0.000002             1
# 1           -0.000969            0.000969           -0.000002             1
# 2            0.000323            0.000969           -0.000002             1
# 3            0.000969            0.000323           -0.000002             1
# 4           -0.000969           -0.000323           -0.000002             1
#
#    source_plate                                     source_s3_path  \
# 0    BR00116991  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
# 1    BR00116991  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
# 2    BR00116991  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
# 3    BR00116991  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
# 4    BR00116991  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
#
#    Metadata_ChannelURLName                                   Metadata_FileUrl  \
# 0              URL_OrigDNA  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
# 1              URL_OrigDNA  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
# 2              URL_OrigDNA  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
# 3              URL_OrigDNA  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
# 4              URL_OrigDNA  s3://cellpainting-gallery/cpg0000-jump-pilot/s...
#
#    Metadata_StainName               Metadata_Filename
# 0       Hoechst 33342  r01c01f01p01-ch5sk1fk1fl1.tiff
# 1       Hoechst 33342  r01c01f02p01-ch5sk1fk1fl1.tiff
# 2       Hoechst 33342  r01c01f03p01-ch5sk1fk1fl1.tiff
# 3       Hoechst 33342  r01c01f04p01-ch5sk1fk1fl1.tiff
# 4       Hoechst 33342  r01c01f05p01-ch5sk1fk1fl1.tiff
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Filter Images to Download
# Keep this as-is to download a small example subset.

# %%
img_metadf = img_metadf.iloc[:10].copy()

# %%
summary = image_downloader.download_images_with_metadata(
    df=img_metadf,
    url_column="Metadata_FileUrl",
    default_output_dir=Path("downloaded_jump_pilot_images"),
    parallel=True,
    workers=8,
)
print(summary)
# Out:
# Rows in dataframe: 10
# Unique TIFF files to process: 10
# Progress 10/10 (downloaded=10, skipped=0, failed=0)
# Done.
# Downloaded: 10
# Skipped:    0
# Failed:     0
# DownloadSummary(total_jobs=10, downloaded=10, skipped=0, failed=0, failures=[])
